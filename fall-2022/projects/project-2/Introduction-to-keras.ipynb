# %% [markdown]
# # Keras
# In this exercise, you will implement a simple neural network using Keras API.
# You’ll go over a fully-connected neural network designed for the MNIST (classifying handwritten digits) dataset.

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

# %% [markdown]
# ## Dataset
#
# In this section, the dataset is loaded and preprocessed. The cells below are already completed.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# The training set will contain 60000 28 by 28 images; we resize this to 60000 by
# 784 since our MLP will take as input a vector of length 784. Similarly, the test
# set, which consists of 10000 images is resized to 10000 by 784.

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
X_train /= 255
X_test /= 255

# %%
numclasses = 10

# %% [markdown]
# We next convert these tensors to floats, and normalize the values to [0, 1].

# %%
y_train = keras.utils.to_categorical(y_train, numclasses)
y_test = keras.utils.to_categorical(y_test, numclasses)

# %% [markdown]
# ## Model
# In this section, you should implement your model using Keras API. [[API documentation]](https://keras.io/api/models/)
#
# ## Steps
# - [ 1 - Implementing](#1)
# - [ 2 - Compiling](#2)
# - [ 3 - Training](#3)
# - [ 4 - Evaluation](#4)

# %% [markdown]
# <a name="1"></a>
# Implement your neural network using Sequential class.

# %% [markdown]
# <a name="2"></a>
# Compile your model using `keras.compile()`.

# %% [markdown]
# <a name="3"></a>
# Train your model using `mode.fit()`.

# %% [markdown]
# <a name="4"></a>
# Evaluate your model using `mode.evaluate()`.
